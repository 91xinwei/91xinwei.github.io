# %% [markdown]
# <a href="https://colab.research.google.com/github/91xinwei/91xinwei.github.io/blob/master/models/notebook/BELLE_INFER_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LianjiaTech/BELLE/blob/main/notebook/BELLE_INFER_COLAB.ipynb)

# %% [markdown]
# # ** BELLE模型在COLAB推理的示例**
# 这里提供在colab环境运行BELLE模型的代码。默认加载的是4bit量化的BLOOM 7B模型，4bit量化的模型目前效果上面还是会有损失。在模型加载到内存过程中，最高消费RAM大概需要8G，等模型load到GPU中以后，RAM只需要4G，GPU大概需要10G。

# %% [markdown]
# ## 查看colab分配的显卡类型，一般免费账户上14G的T4显卡

# %% [markdown]
# ---

# %%
# !nvidia-smi
# Out:
# Fri Feb  7 11:16:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ##  将BELLE项目git clone到colab

# %%
# !git clone https://github.com/LianjiaTech/BELLE.git
# Out:
# Cloning into 'BELLE'...
# remote: Enumerating objects: 2507, done.
# remote: Counting objects: 100% (643/643), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 2507 (delta 491), reused 529 (delta 451), pack-reused 1864 (from 1)
# Receiving objects: 100% (2507/2507), 18.47 MiB | 21.66 MiB/s, done.
# Resolving deltas: 100% (1383/1383), done.

# %% [markdown]
# ### 14G显卡目前只支持量化版本，这里暂时只提供量化版本在colab推理

# %%
# %cd BELLE/models/gptq
# Out:
# /content/BELLE/models/gptq

# %% [markdown]
# ### 安装gptq环境

# %%
# !pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/huggingface/transformers (from -r requirements.txt (line 4))
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-2ua56784
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-2ua56784
#   Resolved https://github.com/huggingface/transformers to commit 014047e1c8784c00e2a04cb04ffcecdd5cb23c16
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting safetensors==0.3.0 (from -r requirements.txt (line 1))
#   Downloading safetensors-0.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting datasets==2.10.1 (from -r requirements.txt (line 2))
#   Downloading datasets-2.10.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (17.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets==2.10.1->-r requirements.txt (line 2))
#   Downloading dill-0.3.6-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (4.67.1)
# Collecting xxhash (from datasets==2.10.1->-r requirements.txt (line 2))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets==2.10.1->-r requirements.txt (line 2))
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets==2.10.1->-r requirements.txt (line 2)) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (3.11.11)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (24.2)
# Collecting responses<0.19 (from datasets==2.10.1->-r requirements.txt (line 2))
#   Downloading responses-0.18.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets==2.10.1->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0->-r requirements.txt (line 4)) (3.17.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.49.0.dev0->-r requirements.txt (line 4)) (0.21.0)
# INFO: pip is looking at multiple versions of transformers to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 4) and safetensors==0.3.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested safetensors==0.3.0
#     transformers 4.49.0.dev0 depends on safetensors>=0.4.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %%
! python setup_cuda.py install && CUDA_VISIBLE_DEVICES=0 && python test_kernel.py
# Out:
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating quant_cuda.egg-info
# writing quant_cuda.egg-info/PKG-INFO
# writing dependency_links to quant_cuda.egg-info/dependency_links.txt
# writing top-level names to quant_cuda.egg-info/top_level.txt
# writing manifest file 'quant_cuda.egg-info/SOURCES.txt'
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:497: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'quant_cuda.egg-info/SOURCES.txt'
# writing manifest file 'quant_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'quant_cuda' extension
# creating build/temp.linux-x86_64-cpython-311
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c quant_cuda.cpp -o build/temp.linux-x86_64-cpython-311/quant_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=quant_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.11 -c quant_cuda_kernel.cu -o build/temp.linux-x86_64-cpython-311/quant_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=quant_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:123:40: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                        ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:154: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/Dispatch.h:109:1: note: declared here
#   109 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:123:1010: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:1031: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:1055: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:1082: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:1105: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:123:1998: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:2019: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:2042: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:2068: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:123:2091: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   123 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:218:40: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                        ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:154: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/Dispatch.h:109:1: note: declared here
#   109 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:218:1010: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:1031: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:1055: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:1082: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:1105: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:218:1998: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:2019: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:2042: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:2068: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:218:2091: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   218 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:377:40: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   377 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                        ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# quant_cuda_kernel.cu:377:154: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   377 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                          ^
# /usr/local/lib/python3.11/dist-packages/torch/include/ATen/Dispatch.h:109:1: note: declared here
#   109 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# ...
#           -1.6531e-01,  2.4013e-01],
#          [ 1.2259e-01, -3.9287e-01,  2.4910e-01,  ...,  6.3514e-01,
#           -4.0377e-01, -3.6705e-02],
#          ...,
#          [ 3.3101e-01, -6.1678e-02,  4.6487e-01,  ..., -5.1708e-01,
#            3.0471e-01, -1.7711e-01],
#          [ 7.6712e-01, -4.5138e-02,  9.1125e-01,  ...,  7.0178e-01,
#           -3.2478e-01,  3.2730e-01],
#          [-7.0755e-01, -6.7507e-01,  7.9443e-01,  ...,  2.0361e-01,
#            4.9189e-01, -1.0199e+00]]], device='cuda:0')
#
#
# 3bit Simu: tensor([[[-8.1857e-01, -4.2099e-01,  1.6457e-01,  ...,  2.9426e-01,
#            1.1556e-01,  6.7775e-04],
#          [-2.3194e-01, -4.1687e-01, -2.9646e-01,  ...,  1.5593e-01,
#            1.4413e-01, -2.9452e-01],
#          [-1.9069e-01,  5.3375e-01,  3.3973e-01,  ...,  4.7055e-01,
#           -8.1298e-01, -1.3063e+00],
#          ...,
#          [-5.0297e-01, -1.9859e-01, -2.8694e-01,  ...,  2.7361e-01,
#            5.7816e-01,  1.1543e-01],
#          [-2.2693e-01,  1.3998e-01, -6.3358e-01,  ..., -8.5482e-01,
#           -8.8673e-03,  2.0080e-01],
#          [ 3.7294e-01,  8.2564e-01,  5.7507e-01,  ..., -6.5445e-01,
#           -5.5399e-01, -1.3971e+00]],
#
#         [[ 2.6603e-01,  4.1408e-01, -1.1204e+00,  ..., -3.4603e-01,
#           -8.5658e-01, -4.9443e-01],
#          [ 2.3421e-01,  1.3475e-01, -6.3763e-01,  ..., -6.1453e-01,
#            6.0309e-01,  3.2441e-01],
#          [-3.2896e-02,  4.2640e-01,  2.0259e-01,  ..., -1.1344e-01,
#            3.1743e-01,  2.8462e-01],
#          ...,
#          [ 7.4563e-01,  2.1575e-01, -2.2541e-01,  ...,  5.3727e-01,
#           -2.2407e-01, -1.1899e-01],
#          [-2.1982e-01,  2.1265e-01,  3.5838e-01,  ...,  1.0974e+00,
#            6.7708e-02, -3.8298e-01],
#          [ 2.8150e-02, -7.3201e-01, -8.5261e-01,  ...,  9.3033e-01,
#           -1.2718e-01, -1.0418e+00]],
#
#         [[ 2.6241e-01, -4.8990e-01, -3.4380e-01,  ..., -5.5409e-01,
#            4.4146e-01,  6.2581e-01],
#          [ 7.9239e-01, -1.3322e+00,  8.0470e-01,  ..., -2.5765e-01,
#           -3.9086e-01, -8.9973e-01],
#          [ 7.9403e-01, -7.7875e-01,  2.4511e-01,  ...,  6.8472e-01,
#           -4.7069e-01,  2.2314e-01],
#          ...,
#          [ 6.3523e-01, -1.5455e-01, -1.0438e+00,  ..., -2.0177e-02,
#           -3.9912e-01, -2.1187e-01],
#          [ 1.2074e-01, -6.0911e-01, -6.3494e-01,  ..., -1.1641e-01,
#            5.0673e-01,  3.3823e-01],
#          [-6.5118e-01, -6.6013e-01, -4.3926e-01,  ..., -4.7176e-02,
#            1.7401e-01,  9.4023e-01]],
#
#         [[-5.5425e-01, -1.7670e-01, -1.7800e-01,  ..., -4.6527e-01,
#            1.6896e-01,  3.3345e-01],
#          [-7.3437e-02,  6.0746e-01,  7.5316e-01,  ..., -1.0109e+00,
#            2.5574e-01,  5.8983e-01],
#          [-5.9899e-01, -2.8435e-01,  4.8529e-02,  ...,  4.2334e-01,
#            1.7481e-01,  9.4320e-01],
#          ...,
#          [ 3.5606e-01, -4.9406e-01,  1.0091e+00,  ...,  2.7307e-01,
#           -5.3612e-01, -2.6591e-01],
#          [-6.4175e-01,  8.2154e-03, -2.1113e+00,  ..., -1.4595e-01,
#           -3.9842e-01,  3.1901e-02],
#          [ 3.3111e-01,  8.2694e-02,  4.3586e-01,  ...,  2.2467e-01,
#           -8.7605e-01, -4.8683e-01]],
#
#         [[-5.9154e-01, -6.1970e-01, -7.7428e-01,  ..., -1.7456e-01,
#           -3.3021e-01,  8.9163e-01],
#          [-1.6332e-01,  5.1702e-01,  8.9615e-01,  ..., -2.5504e-01,
#            1.1462e-01, -8.9469e-02],
#          [-3.8005e-01, -4.4796e-02,  4.9640e-01,  ...,  1.2345e+00,
#           -5.8626e-01,  6.2328e-01],
#          ...,
#          [ 2.2243e-01,  9.4717e-01,  1.1941e-01,  ..., -3.9915e-01,
#            5.9484e-01,  1.4150e-01],
#          [-1.3326e+00, -4.1940e-01,  5.5072e-01,  ..., -1.1668e-01,
#            1.4381e+00, -9.3320e-01],
#          [-7.0398e-01,  1.2485e+00, -4.2538e-02,  ...,  5.0241e-01,
#           -2.0969e-01, -2.4772e-01]]], device='cuda:0')
# 3bit Kern: tensor([[[-8.1857e-01, -4.2099e-01,  1.6457e-01,  ...,  2.9427e-01,
#            1.1556e-01,  6.7763e-04],
#          [-2.3194e-01, -4.1687e-01, -2.9646e-01,  ...,  1.5593e-01,
#            1.4413e-01, -2.9452e-01],
#          [-1.9069e-01,  5.3375e-01,  3.3973e-01,  ...,  4.7055e-01,
#           -8.1298e-01, -1.3063e+00],
#          ...,
#          [-5.0297e-01, -1.9859e-01, -2.8694e-01,  ...,  2.7361e-01,
#            5.7816e-01,  1.1543e-01],
#          [-2.2693e-01,  1.3998e-01, -6.3358e-01,  ..., -8.5482e-01,
#           -8.8672e-03,  2.0080e-01],
#          [ 3.7294e-01,  8.2564e-01,  5.7507e-01,  ..., -6.5445e-01,
#           -5.5399e-01, -1.3971e+00]],
#
#         [[ 2.6603e-01,  4.1408e-01, -1.1204e+00,  ..., -3.4603e-01,
#           -8.5658e-01, -4.9443e-01],
#          [ 2.3421e-01,  1.3475e-01, -6.3763e-01,  ..., -6.1453e-01,
#            6.0309e-01,  3.2440e-01],
#          [-3.2896e-02,  4.2640e-01,  2.0259e-01,  ..., -1.1344e-01,
#            3.1743e-01,  2.8462e-01],
#          ...,
#          [ 7.4563e-01,  2.1575e-01, -2.2541e-01,  ...,  5.3727e-01,
#           -2.2407e-01, -1.1899e-01],
#          [-2.1982e-01,  2.1265e-01,  3.5838e-01,  ...,  1.0974e+00,
#            6.7708e-02, -3.8298e-01],
#          [ 2.8150e-02, -7.3201e-01, -8.5261e-01,  ...,  9.3034e-01,
#           -1.2718e-01, -1.0418e+00]],
#
#         [[ 2.6241e-01, -4.8990e-01, -3.4380e-01,  ..., -5.5409e-01,
#            4.4146e-01,  6.2581e-01],
#          [ 7.9239e-01, -1.3322e+00,  8.0470e-01,  ..., -2.5765e-01,
#           -3.9086e-01, -8.9973e-01],
#          [ 7.9403e-01, -7.7875e-01,  2.4511e-01,  ...,  6.8472e-01,
#           -4.7069e-01,  2.2314e-01],
#          ...,
#          [ 6.3523e-01, -1.5455e-01, -1.0438e+00,  ..., -2.0178e-02,
#           -3.9912e-01, -2.1187e-01],
#          [ 1.2074e-01, -6.0911e-01, -6.3494e-01,  ..., -1.1641e-01,
#            5.0673e-01,  3.3823e-01],
#          [-6.5118e-01, -6.6013e-01, -4.3926e-01,  ..., -4.7176e-02,
#            1.7401e-01,  9.4023e-01]],
#
#         [[-5.5425e-01, -1.7670e-01, -1.7800e-01,  ..., -4.6527e-01,
#            1.6896e-01,  3.3345e-01],
#          [-7.3437e-02,  6.0747e-01,  7.5316e-01,  ..., -1.0109e+00,
#            2.5574e-01,  5.8983e-01],
#          [-5.9899e-01, -2.8435e-01,  4.8529e-02,  ...,  4.2334e-01,
#            1.7481e-01,  9.4320e-01],
#          ...,
#          [ 3.5606e-01, -4.9406e-01,  1.0091e+00,  ...,  2.7307e-01,
#           -5.3612e-01, -2.6591e-01],
#          [-6.4175e-01,  8.2154e-03, -2.1113e+00,  ..., -1.4594e-01,
#           -3.9842e-01,  3.1901e-02],
#          [ 3.3111e-01,  8.2694e-02,  4.3586e-01,  ...,  2.2467e-01,
#           -8.7605e-01, -4.8683e-01]],
#
#         [[-5.9154e-01, -6.1970e-01, -7.7428e-01,  ..., -1.7456e-01,
#           -3.3021e-01,  8.9163e-01],
#          [-1.6332e-01,  5.1702e-01,  8.9615e-01,  ..., -2.5504e-01,
#            1.1462e-01, -8.9469e-02],
#          [-3.8005e-01, -4.4796e-02,  4.9640e-01,  ...,  1.2345e+00,
#           -5.8626e-01,  6.2328e-01],
#          ...,
#          [ 2.2243e-01,  9.4716e-01,  1.1941e-01,  ..., -3.9915e-01,
#            5.9484e-01,  1.4150e-01],
#          [-1.3326e+00, -4.1940e-01,  5.5072e-01,  ..., -1.1668e-01,
#            1.4381e+00, -9.3320e-01],
#          [-7.0398e-01,  1.2485e+00, -4.2538e-02,  ...,  5.0241e-01,
#           -2.0969e-01, -2.4772e-01]]], device='cuda:0')
#
#
# 4bit Simu: tensor([[[ 0.7839,  0.0714,  0.3628,  ..., -0.5435, -0.3276,  0.0387],
#          [ 0.3456,  0.2727, -0.1898,  ..., -0.1957, -0.1045, -0.0554],
#          [-0.6629,  0.3584, -0.1485,  ...,  0.3753, -0.0713,  0.5850],
#          ...,
#          [ 0.7764, -0.1091,  0.6050,  ..., -0.1157,  1.1436, -0.4867],
#          [ 0.5397,  0.9554, -0.0163,  ...,  0.3837, -0.4496,  0.4099],
#          [-0.0680, -0.2105, -0.6519,  ..., -0.9032, -0.3126,  0.0338]],
#
#         [[ 1.0860, -0.4354,  0.1432,  ..., -0.2653,  0.8269, -0.1937],
#          [-0.1027,  1.7393,  0.7834,  ..., -1.2068,  0.6152, -0.0859],
#          [ 0.0256,  0.6859, -0.2015,  ...,  0.0870,  0.6587, -1.0814],
#          ...,
#          [-0.3087, -0.2736,  0.9582,  ..., -0.4181, -0.4628, -0.2427],
#          [-0.6454, -0.2700, -0.2062,  ...,  0.2368,  0.4201,  1.2645],
#          [-0.3271, -0.5138,  0.2171,  ..., -0.0098,  0.3580, -0.6841]],
#
#         [[ 1.3096,  0.3264, -0.5006,  ...,  0.3168,  0.6666, -0.2119],
#          [-0.9504, -0.1235,  0.1987,  ...,  0.5165,  0.3810, -0.3322],
#          [ 0.1209,  0.6036, -0.3768,  ...,  0.7012, -0.0358,  0.8020],
#          ...,
#          [ 0.3900, -0.3072, -1.2719,  ...,  0.7163, -0.2176, -0.2148],
#          [ 0.4275,  0.2027, -0.1738,  ..., -0.6602, -0.3718, -0.1215],
#          [-0.3057, -0.1136, -0.5682,  ..., -0.2500, -0.2413,  0.3374]],
#
#         [[ 0.8629,  0.0144, -0.0882,  ...,  0.0729, -0.0902, -0.5172],
#          [ 0.5889, -0.4165,  0.1832,  ..., -0.4702,  1.5048, -0.2838],
#          [-0.1726, -0.3961,  0.8030,  ...,  0.6664, -0.9895,  0.0051],
#          ...,
#          [ 0.2083,  0.3431,  0.2732,  ...,  0.3619, -0.3711,  0.5901],
#          [ 0.0577,  0.0640, -0.2704,  ...,  0.8412,  0.2327,  0.3636],
#          [ 0.1549,  0.1668, -0.5028,  ..., -1.0663,  0.2571,  0.2646]],
#
#         [[-0.8264,  0.3804, -0.0542,  ...,  0.2318, -0.1155, -0.4790],
#          [-0.3120, -0.2158, -0.3415,  ...,  0.9462,  1.0321, -0.0383],
#          [-0.2565,  0.1206,  0.8749,  ...,  0.1425, -0.0629, -0.1227],
#          ...,
#          [ 0.8050,  0.3583,  0.4777,  ..., -0.0873, -0.4760,  0.4175],
#          [-0.7674,  1.2000,  0.1885,  ..., -0.7521,  0.4816,  1.2807],
#          [ 0.0436,  0.2727, -0.3760,  ..., -0.4270, -0.5830,  0.2085]]],
#        device='cuda:0')
# 4bit Kern: tensor([[[ 0.7839,  0.0714,  0.3628,  ..., -0.5435, -0.3276,  0.0387],
#          [ 0.3456,  0.2727, -0.1898,  ..., -0.1957, -0.1045, -0.0554],
#          [-0.6629,  0.3584, -0.1485,  ...,  0.3753, -0.0713,  0.5850],
#          ...,
#          [ 0.7764, -0.1091,  0.6050,  ..., -0.1157,  1.1436, -0.4867],
#          [ 0.5397,  0.9554, -0.0163,  ...,  0.3837, -0.4496,  0.4099],
#          [-0.0680, -0.2105, -0.6519,  ..., -0.9032, -0.3126,  0.0338]],
#
#         [[ 1.0860, -0.4354,  0.1432,  ..., -0.2653,  0.8269, -0.1937],
#          [-0.1027,  1.7393,  0.7834,  ..., -1.2068,  0.6152, -0.0859],
#          [ 0.0256,  0.6859, -0.2015,  ...,  0.0870,  0.6587, -1.0814],
#          ...,
#          [-0.3087, -0.2736,  0.9582,  ..., -0.4181, -0.4628, -0.2427],
#          [-0.6454, -0.2700, -0.2062,  ...,  0.2368,  0.4201,  1.2645],
#          [-0.3271, -0.5138,  0.2171,  ..., -0.0098,  0.3580, -0.6841]],
#
#         [[ 1.3096,  0.3264, -0.5006,  ...,  0.3168,  0.6666, -0.2119],
#          [-0.9504, -0.1235,  0.1987,  ...,  0.5165,  0.3810, -0.3322],
#          [ 0.1209,  0.6036, -0.3768,  ...,  0.7012, -0.0358,  0.8020],
#          ...,
#          [ 0.3900, -0.3072, -1.2719,  ...,  0.7163, -0.2176, -0.2148],
#          [ 0.4275,  0.2027, -0.1738,  ..., -0.6602, -0.3718, -0.1215],
#          [-0.3057, -0.1136, -0.5682,  ..., -0.2500, -0.2413,  0.3374]],
#
#         [[ 0.8629,  0.0144, -0.0882,  ...,  0.0729, -0.0902, -0.5172],
#          [ 0.5889, -0.4165,  0.1832,  ..., -0.4702,  1.5048, -0.2838],
#          [-0.1726, -0.3961,  0.8030,  ...,  0.6664, -0.9895,  0.0051],
#          ...,
#          [ 0.2083,  0.3431,  0.2732,  ...,  0.3619, -0.3711,  0.5901],
#          [ 0.0577,  0.0640, -0.2704,  ...,  0.8412,  0.2327,  0.3636],
#          [ 0.1549,  0.1668, -0.5028,  ..., -1.0663,  0.2571,  0.2646]],
#
#         [[-0.8264,  0.3804, -0.0542,  ...,  0.2318, -0.1155, -0.4790],
#          [-0.3120, -0.2158, -0.3415,  ...,  0.9462,  1.0321, -0.0383],
#          [-0.2565,  0.1206,  0.8749,  ...,  0.1425, -0.0629, -0.1227],
#          ...,
#          [ 0.8050,  0.3583,  0.4777,  ..., -0.0873, -0.4760,  0.4175],
#          [-0.7674,  1.2000,  0.1885,  ..., -0.7521,  0.4816,  1.2807],
#          [ 0.0436,  0.2727, -0.3760,  ..., -0.4270, -0.5830,  0.2085]]],
#        device='cuda:0')
#
#
# 8bit Simu: tensor([[[-0.7392,  0.4152,  0.6220,  ...,  0.2577, -0.9583,  0.6650],
#          [-0.3224, -0.1816,  0.4228,  ..., -0.6969,  0.0191, -0.2550],
#          [-0.3300,  1.0520, -0.6218,  ...,  0.8611,  1.3274, -0.4359],
#          ...,
#          [ 0.0239, -0.5362, -0.3068,  ..., -0.5543,  0.7527,  0.7871],
#          [ 0.1614, -0.3477,  0.2558,  ..., -0.0585,  0.5696,  0.2356],
#          [ 0.6055, -1.1018,  0.7190,  ..., -0.7166, -0.2580,  0.2569]],
#
#         [[ 0.1831, -0.8565,  0.0200,  ...,  0.6556,  0.1385,  0.1722],
#          [ 0.8774, -0.1166,  0.1455,  ..., -0.7178, -0.4005,  0.4225],
#          [-1.0928, -0.0094,  0.9832,  ...,  0.4057, -0.3334, -0.0082],
#          ...,
#          [ 0.4376,  0.2488,  0.5007,  ...,  0.3671, -0.0868, -1.2057],
#          [ 0.4434,  0.3380,  0.5598,  ..., -0.2271, -0.8984, -0.5779],
#          [-0.0376, -0.2214, -0.2781,  ..., -0.4666,  0.1860, -0.1333]],
#
#         [[ 0.0974, -0.1498, -0.9301,  ...,  0.6424,  0.1026, -0.3758],
#          [ 1.1600,  0.2564, -0.0905,  ..., -0.2737,  0.4876, -0.0985],
#          [-0.4256,  0.3164, -0.1993,  ...,  0.0405, -0.1093,  0.2089],
#          ...,
#          [-0.2904, -0.3443,  0.8687,  ..., -0.5385, -0.7169,  0.9073],
#          [-0.6563,  0.0130,  0.2751,  ...,  0.5510, -0.6508, -0.0317],
#          [ 0.1429, -0.3143,  0.0223,  ...,  0.3575, -0.0485,  0.3208]],
#
#         [[-0.9381, -0.4493, -1.0195,  ...,  0.1399,  0.7409,  0.3959],
#          [-1.0898,  0.6198, -0.4845,  ..., -1.2119,  0.4931, -0.0898],
#          [ 0.2702, -0.4602, -0.4129,  ..., -0.0783,  0.2528,  0.0993],
#          ...,
#          [-0.0984,  0.1731,  0.3160,  ..., -0.5711, -1.2083, -0.2453],
#          [-0.2575,  0.3986, -0.0696,  ...,  0.3441,  0.6526,  0.0196],
#          [-0.1288,  0.2494,  0.2970,  ..., -0.4863, -0.2430,  0.4019]],
#
#         [[ 0.3893, -0.2447,  0.4268,  ...,  0.3134, -0.2986,  1.4809],
#          [ 0.8764, -0.4727,  1.0845,  ...,  0.1594,  0.2020, -1.1085],
#          [ 0.1718, -0.1131, -0.2121,  ...,  0.7338, -0.2564,  1.1070],
#          ...,
#          [-1.0273, -1.0506, -0.7187,  ..., -1.0248,  0.2636, -0.2036],
#          [-0.3259,  0.6312,  0.8457,  ..., -0.1045, -0.3929, -1.0807],
#          [-0.2682, -0.8345, -0.6115,  ...,  0.0128,  0.2516,  0.4182]]],
#        device='cuda:0')
# 8bit Kern: tensor([[[-0.7392,  0.4152,  0.6220,  ...,  0.2577, -0.9583,  0.6650],
#          [-0.3225, -0.1816,  0.4228,  ..., -0.6969,  0.0191, -0.2550],
#          [-0.3300,  1.0520, -0.6218,  ...,  0.8611,  1.3274, -0.4359],
#          ...,
#          [ 0.0239, -0.5362, -0.3068,  ..., -0.5543,  0.7527,  0.7871],
#          [ 0.1614, -0.3477,  0.2558,  ..., -0.0585,  0.5696,  0.2356],
#          [ 0.6055, -1.1018,  0.7190,  ..., -0.7166, -0.2580,  0.2569]],
#
#         [[ 0.1831, -0.8565,  0.0200,  ...,  0.6556,  0.1385,  0.1722],
#          [ 0.8774, -0.1166,  0.1455,  ..., -0.7178, -0.4005,  0.4225],
#          [-1.0928, -0.0094,  0.9832,  ...,  0.4057, -0.3334, -0.0082],
#          ...,
#          [ 0.4376,  0.2488,  0.5007,  ...,  0.3671, -0.0868, -1.2057],
#          [ 0.4434,  0.3380,  0.5598,  ..., -0.2271, -0.8984, -0.5779],
#          [-0.0376, -0.2214, -0.2781,  ..., -0.4666,  0.1860, -0.1333]],
#
#         [[ 0.0974, -0.1498, -0.9301,  ...,  0.6424,  0.1026, -0.3758],
#          [ 1.1600,  0.2564, -0.0905,  ..., -0.2737,  0.4876, -0.0985],
#          [-0.4256,  0.3164, -0.1993,  ...,  0.0405, -0.1093,  0.2089],
#          ...,
#          [-0.2904, -0.3443,  0.8687,  ..., -0.5385, -0.7169,  0.9073],
#          [-0.6563,  0.0130,  0.2751,  ...,  0.5510, -0.6508, -0.0317],
#          [ 0.1429, -0.3143,  0.0223,  ...,  0.3575, -0.0485,  0.3208]],
#
#         [[-0.9381, -0.4493, -1.0195,  ...,  0.1399,  0.7409,  0.3959],
#          [-1.0898,  0.6198, -0.4845,  ..., -1.2119,  0.4931, -0.0898],
#          [ 0.2702, -0.4602, -0.4129,  ..., -0.0783,  0.2528,  0.0993],
#          ...,
#          [-0.0984,  0.1731,  0.3160,  ..., -0.5711, -1.2083, -0.2453],
#          [-0.2575,  0.3986, -0.0696,  ...,  0.3441,  0.6526,  0.0196],
#          [-0.1288,  0.2494,  0.2970,  ..., -0.4863, -0.2430,  0.4019]],
#
#         [[ 0.3893, -0.2447,  0.4268,  ...,  0.3134, -0.2986,  1.4809],
#          [ 0.8764, -0.4727,  1.0845,  ...,  0.1594,  0.2020, -1.1085],
#          [ 0.1718, -0.1131, -0.2121,  ...,  0.7338, -0.2564,  1.1070],
#          ...,
#          [-1.0273, -1.0506, -0.7187,  ..., -1.0248,  0.2636, -0.2036],
#          [-0.3259,  0.6312,  0.8457,  ..., -0.1045, -0.3929, -1.0807],
#          [-0.2682, -0.8345, -0.6115,  ...,  0.0128,  0.2516,  0.4182]]],
#        device='cuda:0')

# %% [markdown]
# ### 将BELLE_BLOOM_GPTQ_4BIT版本下载到colab

# %%
# !git lfs install && git clone https://huggingface.co/BelleGroup/BELLE_BLOOM_GPTQ_4BIT
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'BELLE_BLOOM_GPTQ_4BIT'...
# remote: Enumerating objects: 21, done.
# remote: Total 21 (delta 0), reused 0 (delta 0), pack-reused 21 (from 1)
# Unpacking objects: 100% (21/21), 4.08 MiB | 5.83 MiB/s, done.
# Encountered 1 file(s) that may not have been copied correctly on Windows:
# 	bloom7b-2m-4bit-128g.pt
#
# See: `git lfs help smudge` for more details.

# %%
# !ls BELLE_BLOOM_GPTQ_4BIT
# Out:
# bloom7b-2m-4bit-128g.pt  pytorch_model.bin.index.json  special_tokens_map.json	tokenizer.json
# config.json		 README.md		       tokenizer_config.json

# %%
# !pwd
# Out:
# /content/BELLE/models/gptq

# %% [markdown]
# ##   运行下面的cell，然后在Human后面点击输入你和BELLE的对话内容。

# %%
! python bloom_inference.py BELLE_BLOOM_GPTQ_4BIT  --temperature 1.2  --wbits 4 --groupsize 128 --load  BELLE_BLOOM_GPTQ_4BIT/bloom7b-2m-4bit-128g.pt
# Out:
# 2025-02-07 11:29:26.506395: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738927766.535813    3812 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738927766.545162    3812 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-07 11:29:26.594489: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# Loading model ...
# /content/BELLE/models/gptq/bloom_inference.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint,map_location=torch.device('cuda')))
# Done.
# Human:
# 你好
# Assistant:
#
# "Hello there," I am there to help!</s>
#
# -------------------------------
#
# Human:
# 请问你几岁了
# Assistant:
#
#  我是一个AI语言模型，并没有年龄。</s>
#
# -------------------------------
#
# Human:
# 你是什么大模型
# Assistant:
#
#
# 我是 T5 模型，这是我在比赛中使用的代码名，表示我正在参加以 "Turing" 名为的大模型挑战比赛。</s>
#
# -------------------------------
#
# Human:
